# %% [markdown]
# #Exercise: Restaurant Location vs Daily Revenue

# %% [markdown]
# Goal: Build a random forest regression model to predict daily restaurant revenue based on location characteristics, using the ensemble power of multiple decision trees.

# %% [markdown]
# ##Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ##Importing the dataset

# %%
dataset = pd.read_csv('restaurant_locations_dataset.csv')

# %%
print(dataset)
# Out:
#     Restaurant_ID  Location_Score  Daily_Revenue_$100s
# 0    Restaurant_1              15                  120
# 1    Restaurant_2              25                  180
# 2    Restaurant_3              35                  250
# 3    Restaurant_4              45                  320
# 4    Restaurant_5              55                  450
# 5    Restaurant_6              65                  520
# 6    Restaurant_7              75                  580
# 7    Restaurant_8              85                  620
# 8    Restaurant_9              95                  650
# 9   Restaurant_10              15                  110
# 10  Restaurant_11              25                  190
# 11  Restaurant_12              35                  260
# 12  Restaurant_13              45                  310
# 13  Restaurant_14              55                  440
# 14  Restaurant_15              65                  530
# 15  Restaurant_16              75                  590
# 16  Restaurant_17              85                  610
# 17  Restaurant_18              95                  640
# 18  Restaurant_19              50                  430
# 19  Restaurant_20              60                  540

# %% [markdown]
# ##Creating the matrix of features

# %%
X = dataset.iloc[:, 1:-1].values

# %%
print(X)
# Out:
# [[15]
#  [25]
#  [35]
#  [45]
#  [55]
#  [65]
#  [75]
#  [85]
#  [95]
#  [15]
#  [25]
#  [35]
#  [45]
#  [55]
#  [65]
#  [75]
#  [85]
#  [95]
#  [50]
#  [60]]

# %% [markdown]
# ##Creating the dependent variable vector

# %%
y = dataset.iloc[:, -1].values

# %%
print(y)
# Out:
# [120 180 250 320 450 520 580 620 650 110 190 260 310 440 530 590 610 640
#  430 540]

# %% [markdown]
# ##Building the model

# %% [markdown]
# ###Building the model with 10 estimators

# %%
from sklearn.ensemble import RandomForestRegressor
regressor_10 = RandomForestRegressor(n_estimators=10, random_state=0)

# %% [markdown]
# ###Building the model with 50 estimators

# %%
from sklearn.ensemble import RandomForestRegressor
regressor_50 = RandomForestRegressor(n_estimators=50, random_state=0)

# %% [markdown]
# ###Building the model with 100 estimators

# %%
from sklearn.ensemble import RandomForestRegressor
regressor_100 = RandomForestRegressor(n_estimators=100, random_state=0)

# %% [markdown]
# ##Training the model

# %% [markdown]
# ###Training the model with 10 estimators

# %%
regressor_10.fit(X, y)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %% [markdown]
# ###Training the model with 50 estimators

# %%
regressor_50.fit(X, y)
# Out:
# RandomForestRegressor(n_estimators=50, random_state=0)

# %% [markdown]
# ###Training the model with 100 estimators

# %%
regressor_100.fit(X, y)
# Out:
# RandomForestRegressor(random_state=0)

# %% [markdown]
# ##Making a prediction

# %% [markdown]
# ###Making a prediction for model with 10 estimators

# %%
#Predict revenue for location scores 30, 70, and 90
print(regressor_10.predict([[30]]))
print(regressor_10.predict([[70]]))
print(regressor_10.predict([[90]]))
# Out:
# [198.25]
# [549.95]
# [618.43333333]

# %% [markdown]
# ###Making a prediction for model with 50 estimators

# %%
#Predict revenue for location scores 30, 70, and 90
print(regressor_50.predict([[30]]))
print(regressor_50.predict([[70]]))
print(regressor_50.predict([[90]]))
# Out:
# [193.97]
# [537.57333333]
# [618.55]

# %% [markdown]
# ###Making a prediction for model with 100 estimators

# %%
#Predict revenue for location scores 30, 70, and 90
print(regressor_100.predict([[30]]))
print(regressor_100.predict([[70]]))
print(regressor_100.predict([[90]]))
# Out:
# [192.84166667]
# [532.67833333]
# [617.90833333]

# %% [markdown]
# ##Visualizing the results in higher resolution

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape(len(X_grid), 1)
plt.scatter(X, y, color='red')
plt.plot(X_grid, regressor_10.predict(X_grid), color='blue')
plt.plot(X_grid, regressor_50.predict(X_grid), color='black')
plt.plot(X_grid, regressor_100.predict(X_grid), color='green')
plt.title('Restaurant Location Score vs Daily Revenue')
plt.xlabel('Restaurant Location Score')
plt.ylabel('Daily Revenue')
plt.show()
# Out:
# /tmp/ipython-input-4198904043.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1)

# %% [markdown]
# ###Visualizing the results in higher resolution for model with 10 estimators

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape(len(X_grid), 1)
plt.scatter(X, y, color='red')
plt.plot(X_grid, regressor_10.predict(X_grid), color='blue')
plt.title('Restaurant Location Score vs Daily Revenue')
plt.xlabel('Restaurant Location Score')
plt.ylabel('Daily Revenue')
plt.show()
# Out:
# /tmp/ipython-input-159951982.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1)

# %% [markdown]
# ###Visualizing the results in higher resolution for model with 50 estimators

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape(len(X_grid), 1)
plt.scatter(X, y, color='red')
plt.plot(X_grid, regressor_50.predict(X_grid), color='blue')
plt.title('Restaurant Location Score vs Daily Revenue')
plt.xlabel('Restaurant Location Score')
plt.ylabel('Daily Revenue')
plt.show()
# Out:
# /tmp/ipython-input-3705955289.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1)

# %% [markdown]
# ###Visualizing the results in higher resolution for model with 100 estimators

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape(len(X_grid), 1)
plt.scatter(X, y, color='red')
plt.plot(X_grid, regressor_100.predict(X_grid), color='blue')
plt.title('Restaurant Location Score vs Daily Revenue')
plt.xlabel('Restaurant Location Score')
plt.ylabel('Daily Revenue')
plt.show()
# Out:
# /tmp/ipython-input-2473853665.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1)

# %% [markdown]
# ##Performance Metrics

# %%
from sklearn.metrics import r2_score

# %% [markdown]
# ###R<sup>2</sup> scores

# %%
#Model with 10 estimators
print(r2_score(y, regressor_10.predict(X)))
# Out:
# 0.9917761331148516

# %%
#Model with 50 estimators
print(r2_score(y, regressor_50.predict(X)))
# Out:
# 0.9942670492690195

# %%
#Model with 100 estimators
print(r2_score(y, regressor_100.predict(X)))
# Out:
# 0.994924844595342
